# %%
import os, sys, json
import numpy as np

ROOT_DIR = os.path.abspath("../../")
# %matplotlib inline

import matplotlib.pyplot as plt

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.act import act
DATASET_DIR = os.path.join(ROOT_DIR, "datasets/output-1220-preview")
LOGS_DIR = os.path.join(ROOT_DIR, "logs/")
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
play_dataset = act.ActDataset()
play_dataset.load_subset("/Users/thrivesmart1/Projects/Mask_RCNN/datasets/output-1220-preview", "training")
SHOW_MASK_INDEX = 3
print(play_dataset.image_info[0])
mask_stack, _ = play_dataset.load_mask(0)
_, ax = plt.subplots(1, figsize=(16,16))
height, width = mask_stack.shape[:2]
print("Mask image is ", width, "x", height, "Total shape:", mask_stack.shape)
ax.axis('off')
ax.set_ylim(height + 10, -10)
ax.set_xlim(-10, width + 10)
ax.imshow(mask_stack[...,SHOW_MASK_INDEX])
plt.show()
# Out:
# Loading dataset  /Users/thrivesmart1/Projects/Mask_RCNN/datasets/output-1220-preview/training
# {'id': '0001Color.jpg', 'source': 'act', 'path': '/Users/thrivesmart1/Projects/Mask_RCNN/datasets/output-1220-preview/training/0001Color.jpg', 'width': 512, 'height': 512, 'prefix': '0001', 'prefix_dir': '/Users/thrivesmart1/Projects/Mask_RCNN/datasets/output-1220-preview/training'}
# Mask image is  512 x 512 Total shape: (512, 512, 47)

# %%
COMPONENTS_WEIGHTS_FILE = os.path.join(ROOT_DIR, "temp/nespresso_vertuo/components-model/mask_rcnn_nespresso_vertuo_0030.h5")
VARIANTS_WEIGHTS_FILE = os.path.join(ROOT_DIR, "temp/nespresso_vertuo/variants-model/mask_rcnn_greppy_0030.h5")
WEIGHTS_FILE = VARIANTS_WEIGHTS_FILE if MODEL_TRAINED_ON_VARIANTS_NOT_COMPONENTS else COMPONENTS_WEIGHTS_FILE

dataset_dict = json.load(open(os.path.join(DATASET_DIR, '_dataset.json')))
class InferenceConfig(greppy.GreppyConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    TRAINED_ON_VARIANTS_NOT_COMPONENTS = MODEL_TRAINED_ON_VARIANTS_NOT_COMPONENTS
    VARIANT_URIS = dataset_dict['variant_uris']
    COMPONENT_URIS = dataset_dict['component_uris']
    NUM_CLASSES = (1 + len(dataset_dict['variant_uris'])) if MODEL_TRAINED_ON_VARIANTS_NOT_COMPONENTS else (1 + len(dataset_dict['component_uris']))
    IS_STEREO_CAMERA = dataset_dict['camera']['is_stereo_camera']
    # Skip detections with < 100% confidence -- go for the gold!
    DETECTION_MIN_CONFIDENCE = .999
config = InferenceConfig()
model = modellib.MaskRCNN(mode="inference", config=config, model_dir=LOGS_DIR)
model.load_weights(WEIGHTS_FILE, by_name=True)

# %%
channels = [
    np_color_data[..., 2].astype(np.float32), # flip to BGR
    np_color_data[..., 1].astype(np.float32),
    np_color_data[..., 0].astype(np.float32),
    np_depth_data.astype(np.float32)
]
image4chan = np.stack(channels, axis=-1)
r = model.detect([image4chan], verbose=1)[0]
# Color splash
# Save image with masks
class_names = config.__class__.VARIANT_URIS if MODEL_TRAINED_ON_VARIANTS_NOT_COMPONENTS else config.__class__.COMPONENT_URIS
visualize.display_instances(
    np_color_data[...,::-1], r['rois'], r['masks'], r['class_ids'],
    class_names, r['scores'],
    show_bbox=True, show_mask=True,
    title="Predictions")
# Out:
# Processing 1 images
# image                    shape: (720, 1280, 4)        min:    0.00000  max:  255.00000  float32
# molded_images            shape: (1, 1024, 1024, 4)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 15)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
